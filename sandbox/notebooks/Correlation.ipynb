# %%
import pandas as pd
import pickle
from plotly.offline import iplot, init_notebook_mode
import plotly.graph_objs as go
import plotly.io as pio
import numpy as np
from numpy import arange,array,ones
from scipy.stats import linregress

init_notebook_mode(connected=True)

florida = pickle.load(open("../data/florida.pkl", "rb"))
alberta = pickle.load(open("../data/alberta.pkl", "rb"))

frames = [florida, alberta]

data = pd.concat(frames)

# %%
x=data['Total Nitrogen (ug/L)']
y=data['Microcystin (ug/L)']

layout = go.Layout(
    title="Microcystin vs Nitrogen", 
    xaxis={'title':'Total Nitrogen (ug/L)'}, 
    yaxis={'title':'Microcystin (ug/L)'}
)

points = go.Scatter(
    x=x,
    y=y,
    mode='markers',
    marker={
   'opacity': 0.6,
   'colorscale': 'Viridis'
    },
    name='Data'
)

mask = ~np.isnan(x) & ~np.isnan(y)
regression = stats.linregress(x[mask], y[mask])
line = regression.slope*x+regression.intercept

line = go.Scatter(
    x=x,
    y=line,
    mode='lines',
    line=dict(color='blue', width=2),
    name='Linear Regression'
)

fig = {
    'data': [points, line],
    'layout': layout
}

iplot(fig)

# %%
x=data['Total Phosphorus (ug/L)']
y=data['Microcystin (ug/L)']

layout = go.Layout(
    title="Microcystin vs Phosphorus", 
    xaxis={'title':'Total Phosphorus (ug/L)'}, 
    yaxis={'title':'Microcystin (ug/L)'}
)

points = go.Scatter(
    x=x,
    y=y,
    mode='markers',
    marker={
   'opacity': 0.6,
   'colorscale': 'Viridis'
    },
    name='Data'
)

mask = ~np.isnan(x) & ~np.isnan(y)
regression = stats.linregress(x[mask], y[mask])
line = regression.slope*x+regression.intercept

line = go.Scatter(
    x=x,
    y=line,
    mode='lines',
    line=dict(color='blue', width=2),
    name='Linear Regression'
)

fig = {
    'data': [points, line],
    'layout': layout
}

iplot(fig)

# %%
x=data['Total Chlorophyll (ug/L)']
y=data['Microcystin (ug/L)']

layout = go.Layout(
    title="Microcystin vs Chlorophyll", 
    xaxis={'title':'Total Chlorophyll (ug/L)'}, 
    yaxis={'title':'Microcystin (ug/L)'}
)

points = go.Scatter(
    x=x,
    y=y,
    mode='markers',
    marker={
   'opacity': 0.6,
   'colorscale': 'Viridis'
    },
    name='Data'
)

mask = ~np.isnan(x) & ~np.isnan(y)
regression = stats.linregress(x[mask], y[mask])
line = regression.slope*x+regression.intercept

line = go.Scatter(
    x=x,
    y=line,
    mode='lines',
    line=dict(color='blue', width=2),
    name='Linear Regression'
)

fig = {
    'data': [points, line],
    'layout': layout
}

iplot(fig)

# %%
x=data['Secchi Depth (m)']
y=data['Microcystin (ug/L)']

layout = go.Layout(
    title="Microcystin vs Secchi Depth", 
    xaxis={'title':'Secchi Depth (m)'}, 
    yaxis={'title':'Microcystin (ug/L)'}
)

points = go.Scatter(
    x=x,
    y=y,
    mode='markers',
    marker={
   'opacity': 0.6,
   'colorscale': 'Viridis'
    },
    name='Data'
)

mask = ~np.isnan(x) & ~np.isnan(y)
regression = stats.linregress(x[mask], y[mask])
line = regression.slope*x+regression.intercept

line = go.Scatter(
    x=x,
    y=line,
    mode='lines',
    line=dict(color='blue', width=2),
    name='Linear Regression'
)

fig = {
    'data': [points, line],
    'layout': layout
}

iplot(fig)
